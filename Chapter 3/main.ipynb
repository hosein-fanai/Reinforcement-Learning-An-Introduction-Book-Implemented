# %% [markdown]
# # Chapter 3

# %%
from grid_world.environment import Environment
from grid_world.agent import Agent


env = Environment()
agent = Agent()

# %% [markdown]
# ## Figure 3.2

# %%
agent.learn_pi_value_function(env=env, policy=lambda state: (0.25, 0.25, 0.25, 0.25))
agent.show_value_function()
# Out:
# ________________________________________________________________________________
# |	3.31	|	8.79	|	4.43	|	5.32	|	1.49	|
# |_______________|_______________|_______________|_______________|_______________|
# |	1.52	|	2.99	|	2.25	|	1.91	|	0.55	|
# |_______________|_______________|_______________|_______________|_______________|
# |	0.05	|	0.74	|	0.67	|	0.36	|	-0.40	|
# |_______________|_______________|_______________|_______________|_______________|
# |	-0.97	|	-0.44	|	-0.35	|	-0.59	|	-1.18	|
# |_______________|_______________|_______________|_______________|_______________|
# |	-1.86	|	-1.35	|	-1.23	|	-1.42	|	-1.98	|
# |_______________|_______________|_______________|_______________|_______________|

# %% [markdown]
# ## Figure 3.5

# %%
agent.learn_optimal_value_function(env=env)
agent.show_value_function()
# Out:
# ________________________________________________________________________________
# |	21.98	|	24.42	|	21.98	|	19.42	|	17.48	|
# |_______________|_______________|_______________|_______________|_______________|
# |	19.78	|	21.98	|	19.78	|	17.80	|	16.02	|
# |_______________|_______________|_______________|_______________|_______________|
# |	17.80	|	19.78	|	17.80	|	16.02	|	14.42	|
# |_______________|_______________|_______________|_______________|_______________|
# |	16.02	|	17.80	|	16.02	|	14.42	|	12.98	|
# |_______________|_______________|_______________|_______________|_______________|
# |	14.42	|	16.02	|	14.42	|	12.98	|	11.68	|
# |_______________|_______________|_______________|_______________|_______________|

# %%
optimal_policy = agent.compute_policy(env)
Agent.show_policy(optimal_policy, env)
# Out:
# ________________________________________________________________________________
# |	E	|	W N E S	|	W	|	W N E S	|	W	|
# |_______________|_______________|_______________|_______________|_______________|
# |	N E	|	N	|	W N	|	W	|	W	|
# |_______________|_______________|_______________|_______________|_______________|
# |	N E	|	N	|	W N	|	W N	|	W N	|
# |_______________|_______________|_______________|_______________|_______________|
# |	N E	|	N	|	W N	|	W N	|	W N	|
# |_______________|_______________|_______________|_______________|_______________|
# |	N E	|	N	|	W N	|	W N	|	W N	|
# |_______________|_______________|_______________|_______________|_______________|

# %% [markdown]
# ## An example run for the optimal policy

# %%
agent.run_policy(env, optimal_policy, render=True)
# Out:
# ________________________________________________________________________________
# |	 	|	 A 	|	 	|	 B 	|	 X 	|
# |_______________|_______________|_______________|_______________|_______________|
# |	 	|	 	|	 	|	 	|	 	|
# |_______________|_______________|_______________|_______________|_______________|
# |	 	|	 	|	 	|	 B` 	|	 	|
# |_______________|_______________|_______________|_______________|_______________|
# |	 	|	 	|	 	|	 	|	 	|
# |_______________|_______________|_______________|_______________|_______________|
# |	 	|	 A` 	|	 	|	 	|	 	|
# |_______________|_______________|_______________|_______________|_______________|
# Step: 1, Current Reward: 0.0, Total Rewards: 0.0
# ________________________________________________________________________________
# |	 	|	 A 	|	 	|	 X B 	|	 	|
# |_______________|_______________|_______________|_______________|_______________|
# |	 	|	 	|	 	|	 	|	 	|
# |_______________|_______________|_______________|_______________|_______________|
# ...
